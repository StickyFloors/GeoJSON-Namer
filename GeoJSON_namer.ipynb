# %%
import geopandas as gpd
geojson = gpd.read_file('YOUR PATH')
print(geojson['CHECK YOUR COLUMN NAME'])
geojson_renamed = geojson.rename(columns={'OLD COLUMN NAME': 'name'})
# Out:
# 0                     ELLIS HOTEL
# 1                   GENESIS HOTEL
# 2                  PERSHING HOTEL
# 3                     REGAL HOTEL
# 4                     ANNEX HOTEL
# 5                      WARD HOTEL
# 6                  CRESCENT HOTEL
# 7                    LEONIDE APTS
# 8                    SIMONE HOTEL
# 9                 ST MARK'S HOTEL
# 10                     HART HOTEL
# 11              THE SANBORN HOTEL
# 12                  OLYMPIA HOTEL
# 13                   MARION HOTEL
# 14                COURTLAND HOTEL
# 15                     CASA HEIWA
# 16                   EDWARD HOTEL
# 17        NORBO HOTEL DEVELOPMENT
# 18                   WELDON HOTEL
# 19                 ROSSMORE HOTEL
# 20                 THE BOYD HOTEL
# 21                   PALMER HOUSE
# 22                  LINCOLN HOTEL
# 23                 SOUTHERN HOTEL
# 24                   EUGENE HOTEL
# 25                ST GEORGE HOTEL
# 26               BROWNSTONE HOTEL
# ...

# %%
geojson_renamed
# Out:
#               HUD_ID                         name              PROJ_ADD  \
# 0    17  CAA19890105                  ELLIS HOTEL        802 E SIXTH ST
# 1    19  CAA19890120                GENESIS HOTEL         456 S MAIN ST
# 2    23  CAA19890230               PERSHING HOTEL         502 S MAIN ST
# 3    24  CAA19890255                  REGAL HOTEL        815 E SIXTH ST
# 4    44  CAA19910116                  ANNEX HOTEL     518 SAN JULIAN ST
# 5    51  CAA19910153                   WARD HOTEL           512 WALL ST
# 6    54  CAA19920060               CRESCENT HOTEL        617 E FIFTH ST
# 7    56  CAA19920155                 LEONIDE APTS         512 S MAIN ST
# 8    58  CAA19920245                 SIMONE HOTEL     520 SAN JULIAN ST
# 9    59  CAA19920250              ST MARK'S HOTEL        611 E FIFTH ST
# 10   60  CAA19920285                   HART HOTEL       508 E FOURTH ST
# 11   62  CAA19920305            THE SANBORN HOTEL         526 S MAIN ST
# ...

# %%
geojson_renamed.to_file("new path", driver="GeoJSON")
